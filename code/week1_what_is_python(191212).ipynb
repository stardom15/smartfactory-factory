# %% [markdown]
# # 스마트팩토리 스터디 1일차
# ---
# ### 2019.12.12 <h4>(made by. 정민수)</h4>

# %% [markdown]
# ### 들어가기 전에...

# %% [markdown]
# ### 주피터노트북(Jupyter Notebook)?
#
#  : 프로그램 코드를 브라우저에서 실행해주는 대화식 환경.(셀 단위 실행)
#
# 상단 탭에 있는 [Help] - [Keyboard ShortCuts] 에서 단축키를 확인할 수 있다.

# %% [markdown]
# **자주 사용하는 단축키**
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ch1. 파이썬이란 무엇인가?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 파이썬(Python)은 1990년 암스테르담의 귀도 반 로섬(Guido Van Rossum)이 개발한 인터프리터 언어...
#
# ## 왜 배워요? : 우리는! 직접 데이터 분석을 하고, 분석 플랫폼을 구축하는 수단으로써 배웁니다.
#
# **파이썬(Python) 장점** :
# 1) 배우기 쉬워서 학습용으로 좋다.
# 2) 공동 작업과 유지 보수가 아주 쉽고 편해서 생산성이 높고 실사용률도 높다.
# 3) 읽고 쓰기 쉽다.
# 4) 동적 타입으로 인해 유연하다.
# 5) C라이브러리 함수 call이 굉장이 쉽다.
#
# <u>※ 동적 타입?</u> : 자료형을 지정하는 경우. 컴파일 시, 자료형이 맞지 않으면 오류

# %% [markdown]
# ### 1. 파이썬 다운로드

# %% [markdown]
# 파이썬 공식 홈페이지에서 다운로드 받을 수 있지만,
# 우리는 아나콘다3를 다운받아 python3.7 version을 다운받는다. https://www.anaconda.com/distribution/

# %% [markdown]
# **1) 파이썬 버전확인하기** : anaconda prompt 창에서 python --version 입력

# %% [markdown]
# ### 2. 파이썬 프로그래밍의 기초, 자료형
# 어떤 프로그래밍 언어든 "그 언어의 자료형을 알고 이해할 수 있다면 그 언어의 절반을 터득한 것이나 다름없다."

# %% [markdown]
# ### 숫자형

# %%
# 정수형
a = 123
b = -1024
c = 0

# %%
# 실수형
a = 1.2
b = -3.5
c = 2e-3 # 2*10^(-3)

# %% [markdown]
# ### 연산자

# %%
# 사칙연산
a = 3
b = 2
c = a + b

# %%
a = 3
b = 2
c = a * b

# %%
a = 10
b = 3
c = a / b

# %%
# 제곱
a = 3
b = 4
c = a ** b

# %%
# 나머지 연산자
7 % 3

# %%
# 몫 연산자
7 // 3

# %% [markdown]
# <h3>문제1) 15648944을 45646로 나눈 몫과 나머지를 출력하시오.</h3>

# %%
print(15648944 % 45646)
print(15648944 // 45646)
# Out:
# 38012
# 342

# %% [markdown]
# <h3>문제2) 아래 문제의 답을 출력하시오.</h3>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (힌트) 제곱근(루트) 사용법

# %%
import math

# %%
math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
x = 2

# %%
x ** 2
# Out:
# 4
